# %%
import pandas as pd
import csv

# %%
ifile = open("/home/khyati/Documents/CS_599/CS599-UFOs-PA1/Processing_PDF/output_1870_1950.csv",'rb')

# %%
df = pd.read_csv(ifile)

# %%
df
# Out:
#                     Name        1870        1880            1890        1900  \
# 0                Alabama     996,992   1,262,505       1,513,017   1,828,697
# 1                 Alaska         NaN         NaN          33,426      32,052
# 2                Arizona       9,658      40,440          88,243     122,931
# 3               Arkansas     484,471     802,525       1,128,211   1,311,564
# 4             California     560,247     864,694       1,213,398   1,485,053
# 5               Colorado      39,864     194,327         413,249     539,700
# 6            Connecticut     537,454     622,700         746,258     908,420
# 7               Delaware     125,015     146,608         168,493     184,735
# 8   District of Columbia     131,700     177,624         230,392     278,718
# 9                Florida     187,748     269,493         391,422     528,542
# 10               Georgia   1,184,109   1,542,180       1,837,353   2,216,331
# ...

# %%
#pop_year_wise_every_state = df.iloc[1,0:]
year = [1870, 1880, 1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010]

# %%
ofile = open("/home/khyati/Documents/CS_599/CS599-UFOs-PA1/data/population_dataset/pop_final.csv", "w" )
writer = csv.writer(ofile, delimiter=',')
writer.writerow(['state','year','population'])
for index,row in df.iterrows():
    each_row = list(df.iloc[index,:])
    state = each_row[0]
    for i in zip(year, each_row[1:]):
        row = [each_row[0],i[0],i[1]]
        print row
        writer.writerow(row)
ofile.close()
ifile.close()
# Out:
# ['Alabama', 1870, '996,992']
# ['Alabama', 1880, '1,262,505']
# ['Alabama', 1890, '1,513,017']
# ['Alabama', 1900, '1,828,697']
# ['Alabama', 1910, '2,138,093']
# ['Alabama', 1920, '2,348,174']
# ['Alabama', 1930, '2,646,248']
# ['Alabama', 1940, '2,832,961']
# ['Alabama', 1950, '3,061,743']
# ['Alabama', 1960, '3,266,740']
# ['Alabama', 1970, '3,444,165']
# ['Alabama', 1980, '3,893,888']
# ['Alabama', 1990, '4,040,587']
# ['Alabama', 2000, '4,447,100']
# ['Alabama', 2010, '4,779,736']
# ['Alaska', 1870, nan]
# ['Alaska', 1880, nan]
# ['Alaska', 1890, '33,426']
# ['Alaska', 1900, '32,052']
# ['Alaska', 1910, '64,356']
# ['Alaska', 1920, '55,036']
# ['Alaska', 1930, '59,278']
# ['Alaska', 1940, '72,524']
# ['Alaska', 1950, '128,643']
# ['Alaska', 1960, '226,167']
# ['Alaska', 1970, '300,382']
# ['Alaska', 1980, '401,851']
# ['Alaska', 1990, '550,043']
# ['Alaska', 2000, '626,932']
# ['Alaska', 2010, '710,231']
# ['Arizona', 1870, '9,658']
# ['Arizona', 1880, '40,440']
# ...
